# %% [markdown]
# Polynomial regression is a form of linear regression where only due to the Non-Linear relationship between dependent and independent variables,we add some polynomial term to linear regression to convert it into Polynomial Regression.

# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
df=pd.read_csv('Position_Salaries.csv')

# %%
print(df.isna().sum())
print('Size of dataset:',df.shape)
# Out:
# Position    0
# Level       0
# Salary      0
# dtype: int64
# Size of dataset: (10, 3)

# %%
print(df.head())
df.describe().T
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000
#         count      mean            std      min       25%       50%  \
# Level    10.0       5.5       3.027650      1.0      3.25       5.5
# Salary   10.0  249500.0  299373.883668  45000.0  65000.00  130000.0
#
#               75%        max
# Level        7.75       10.0
# Salary  275000.00  1000000.0

# %%
x=df.iloc[:,1:2].values
y=df.iloc[:,-1].values

# %% [markdown]
# # Training the Linear Regression Model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Training the Polynomial Linear Regression Model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=2)
x_poly=poly_reg.fit_transform(x)

lin_reg2=LinearRegression()
lin_reg2.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Visualizing the Linear Regression Model

# %%
plt.scatter(x,y,color='r')
plt.plot(x,lin_reg.predict(x),color='b')
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.title("Truth or Bluf(Linear Regression)")
plt.show()

# %% [markdown]
# # Visualizing the Polynomial Linear Regression Model Result

# %%
plt.scatter(x,y,color='r')
plt.plot(x,lin_reg2.predict(poly_reg.fit_transform(x)),color='b')
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.title("Truth or Bluf(Linear Regression)")
plt.show()

# %% [markdown]
# # Visulizing the Polynomial Linear Regression Model Result(For Higher Resolution and Smoother Curve)

# %%
x_grid=np.arange(min(x),max(x),0.1)
x_grid=x_grid.reshape((len(x_grid),1))
plt.scatter(x,y,color='r')
plt.plot(x_grid,lin_reg2.predict(poly_reg.fit_transform(x_grid)),color='b')
plt.show()

# %% [markdown]
# # Predicting the new result with Linear Regression

# %%
np.round(lin_reg.predict([[7]]),3)
# Out:
# array([370818.182])

# %% [markdown]
# # Predicting the new result with Polynomial Linear Regression

# %%
np.round(lin_reg2.predict(poly_reg.fit_transform([[7]])),3)
# Out:
# array([254227.273])

# %% [markdown]
# There is a huge difference between the prediction of both values.
